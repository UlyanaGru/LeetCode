# %% [markdown]
# ### find-the-difference-of-two-arrays

# %% [markdown]
# Given two 0-indexed integer arrays nums1 and nums2, return a list answer of size 2 where:
#
# - answer[0] is a list of all distinct integers in nums1 which are not present in nums2.
# - answer[1] is a list of all distinct integers in nums2 which are not present in nums1.\
# Note that the integers in the lists may be returned in any orde

# %%
def findDifference(nums1, nums2):
        """
        :type nums1: List[int]
        :type nums2: List[int]
        :rtype: List[List[int]]
        """
        nums1s=set(nums1)
        nums2s=set(nums2)
        return [list(nums1s-nums2s),list(nums2s-nums1s)]

# %%
nums1 = [1,2,3]
nums2 = [2,4,6]
findDifference(nums1, nums2)
# Out:
# [[1, 3], [4, 6]]

# %% [markdown]
# This solution accepted with 11 ms Beats 48.75%

# %% [markdown]
# ### unique-number-of-occurrences

# %% [markdown]
# Given an array of integers arr, return true if the number of occurrences of each value in the array is unique or false otherwise.

# %%
def uniqueOccurrences(arr):
        """
        :type arr: List[int]
        :rtype: bool
        """
        quant={}
        for i in range(len(arr)):
                if arr[i] in quant.keys():
                        quant[arr[i]] += 1
                else: quant[arr[i]] = 0
        if len(set(quant.values())) == len(set(arr)):
                return True
        return False

# %% [markdown]
# This solution accepted with 7 ms Beats 11.98%

# %%
def uniqueOccurrences(arr):
        """
        :type arr: List[int]
        :rtype: bool
        """
        quant={}
        for num in arr:
                quant[num] = quant.get(num,0)+1
        seen=set()
        for freq in quant.values():
                if freq in seen: return False
                seen.add(freq)
        return True

# %% [markdown]
# This solution accepted with 1 ms Beats 42.40%

# %% [markdown]
# ### determine-if-two-strings-are-close

# %% [markdown]
# Two strings are considered close if you can attain one from the other using the following operations:
#
# Operation 1: Swap any two existing characters.\
# For example, abcde -> aecdb\
# Operation 2: Transform every occurrence of one existing character into another existing character, and do the same with the other character.
# For example, aacabb -> bbcbaa (all a's turn into b's, and all b's turn into a's)\
# You can use the operations on either string as many times as necessary.
#
# Given two strings, word1 and word2, return true if word1 and word2 are close, and false otherwise.

# %%
def closeStrings(word1, word2):
        """
        :type word1: str
        :type word2: str
        :rtype: bool
        """
        quant1={}
        quant2={}
        len1=len(word1)
        len2=len(word2)
        if len1==len2:
            for sym in word1:
                quant1[sym]=quant1.get(sym,0)+1
            for sym in word2:
                quant2[sym]=quant2.get(sym,0)+1
            if sorted(quant1.values()) == sorted(quant2.values()) and sorted(quant1.keys()) == sorted(quant2.keys()):
                #return quant1
                return True
        return False

# %%
word1 ="cabbba"
word2 ="abbccc"
closeStrings(word1, word2)
# Out:
# True

# %%
word1 ="abc"
word2 ="bca"
closeStrings(word1, word2)
# Out:
# True

# %% [markdown]
# This solution accepted with 238 ms Beats 62.46%

# %%
def closeStrings(word1, word2):
        """
        :type word1: str
        :type word2: str
        :rtype: bool
        """
        cnt1=[0]*26
        cnt2=[0]*26
        pr1=[False]*26
        pr2=[False]*26
        for ch in word1:
                id=ord(ch)-ord('a')
                cnt1[id]+=1
                pr1[id]=True
        for ch in word2:
                id=ord(ch)-ord('a')
                cnt2[id]+=1
                pr2[id]=True
        freq1=sorted([cnt for cnt in cnt1 if cnt1>0])
        freq2=sorted([cnt for cnt in cnt2 if cnt2>0])
        if pr1==pr2 and freq1==freq2: return True
        return False

# %% [markdown]
# This solution accepted with 310 ms Beats 40.62%

# %%
import java.util.*;

public class javamodetasks {
    public boolean closeStrings(String word1, String word2){
        HashMap<Character,Integer> quant1 = new HashMap<>();
        HashMap<Character,Integer> quant2 = new HashMap<>();
        int len1 = word1.length(); //with Integer problems with length, on contrary with int all's ok
        int len2 = word2.length();
        if (len1 != len2){
            return false;
        }
        for (char ch1: word1.toCharArray()){
            quant1.put(ch1,quant1.getOrDefault(ch1,0)+1);
        }
        for (char ch2: word2.toCharArray()){
            quant2.put(ch2,quant2.getOrDefault(ch2,0)+1);
        }
        if (!(quant1.keySet()).equals(quant2.keySet())){
            return false;
        }
        List<Integer> freq1 = new ArrayList<>(quant1.values());
        List<Integer> freq2 = new ArrayList<>(quant2.values());
        Collections.sort(freq1);
        Collections.sort(freq2);
        
        return freq1.equals(freq2);

    }
    public static void main(String[] args){
        javamodetasks sol = new javamodetasks();
        System.out.println(sol.closeStrings("aaabbbc", "bcccaaa"));
        System.out.println(sol.closeStrings("aa", "a"));
        System.out.println(sol.closeStrings("...", "..."));
    }
}

# %% [markdown]
# This solution accepted with 67 ms Beats 38.00%

# %% [markdown]
# ### equal-row-and-column-pairs

# %% [markdown]
# Given a 0-indexed n x n integer matrix grid, return the number of pairs (ri, cj) such that row ri and column cj are equal.\
# A row and column pair is considered equal if they contain the same elements in the same order (i.e., an equal array).

# %%
def equalPairs(grid):
        """
        :type grid: List[List[int]]
        :rtype: int
        """
        lengr = len(grid)
        listgr = []
        cnt=0
        for i in range(lengr):
                for j in range(lengr):
                        col = [grid[k][j] for k in range(lengr)]
                        if grid[i] == col:
                                listgr.append((i,j))
                                cnt+=1
        #return list(listgr)
        return cnt

# %%
grid=[[3,2,1],[1,7,6],[2,7,7]]
equalPairs(grid)
# Out:
# 1

# %% [markdown]
# This solution accepted with 3148 ms Beats 5.13%
