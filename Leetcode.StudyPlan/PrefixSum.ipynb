# %% [markdown]
# ### find-the-highest-altitude

# %% [markdown]
# There is a biker going on a road trip. The road trip consists of n + 1 points at different altitudes. The biker starts his trip on point 0 with altitude equal 0.
#
# You are given an integer array gain of length n where gain[i] is the net gain in altitude between points i​​​​​​ and i + 1 for all (0 <= i < n). Return the highest altitude of a point

# %%
def largestAltitude(gain):
        """
        :type gain: List[int]
        :rtype: int
        """
        alt=[0]
        maxalt=alt[0]
        for i in range(len(gain)):
                alt.append(alt[i] + gain[i])
                if alt[i+1]>maxalt: maxalt=alt[i+1]
        return maxalt

# %%
gain = [-5,1,5,0,-7] #1
#The altitudes are [0,-5,-4,1,1,-6]
largestAltitude(gain)
# Out:
# 1

# %%
gain = [-4,-3,-2,-1,4,3,2] #0
#The altitudes are [0,-4,-7,-9,-10,-6,-3,-1]
largestAltitude(gain)
# Out:
# 0

# %%
gain = [44,32,-9,52,23,-50,50,33,-84,47,-14,84,36,-62,37,81,-36,-85,-39,67,-63,64,-47,95,91,-40,65,67,92,-28,97,100,81] #781
largestAltitude(gain)
# Out:
# 781

# %% [markdown]
# This solution was accepted with 0 ms Beats 100%
