# %% [markdown]
# ### move-zeroes

# %% [markdown]
# Given an integer array nums, move all 0's to the end of it while maintaining the relative order of the non-zero elements.
#
# Note that you must do this in-place without making a copy of the array.

# %%
def moveZeroes(nums):
        """
        :type nums: List[int]
        :rtype: None Do not return anything, modify nums in-place instead.
        """
        len_nums = len(nums)
        k=0
        for i in range(len_nums-1,-1,-1):
                if nums[i] == 0: 
                       nums.remove(nums[i])
                       k+=1
        nums.extend(k*[0])
        return nums

# %%
nums = [0,1,0,3,12]
moveZeroes(nums)
# Out:
# [1, 3, 12, 0, 0]

# %% [markdown]
# This solution was accepted with 403 ms Beats 14.31%

# %%
def moveZeroes(nums):
        """
        :type nums: List[int]
        :rtype: None Do not return anything, modify nums in-place instead.
        """
        start=0
        stop=len(nums)
        count=0
        while start<stop:
                if nums[start]==0:
                        nums.pop(start)
                        count+=1
                        stop-=1
                else:
                        start+=1
        nums.extend([0]*count)
        return nums

# %%
nums = [0,1,0,3,12]
moveZeroes(nums)
# Out:
# [1, 3, 12, 0, 0]

# %% [markdown]
# This solution was accepted with 15 ms Beats 22.77%

# %%
def moveZeroes(nums):
        """
        :type nums: List[int]
        :rtype: None Do not return anything, modify nums in-place instead.
        """
        non_zero_pos = 0
        for i in range(len(nums)):
            if nums[i] != 0:
                nums[non_zero_pos] = nums[i]
                non_zero_pos += 1
        for i in range(non_zero_pos, len(nums)):
            nums[i] = 0
        return nums

# %%
nums = [0,1,0,3,12]
moveZeroes(nums)
# Out:
# [1, 3, 12, 0, 0]

# %% [markdown]
# This solution was accepted with 7 ms Beats 59.57%

# %% [markdown]
# ### is-subsequence

# %% [markdown]
# Given two strings s and t, return true if s is a subsequence of t, or false otherwise.
#
# A subsequence of a string is a new string that is formed from the original string by deleting some (can be none) of the characters without disturbing the relative positions of the remaining characters. (i.e., "ace" is a subsequence of "abcde" while "aec" is not).

# %%
def isSubsequence(s, t):
        """
        :type s: str
        :type t: str
        :rtype: bool
        """
        a=len(t)
        b=0
        c=0
        d=len(s)
        if a == 0 and d == 0:
                return True
        elif d == 0:
                return True
        elif a == 0 or a<d:
                return False
        while b<a and c<len(s):
                #print(b)
                if t[b] == s[c]:
                        c+=1
                if c == a:
                        return True
                b+=1
                #print(b,' ',c)
        if c == len(s):
                return True
        return False

# %%
s = "axc"
t = "ahbgdc"
isSubsequence(s, t)
# Out:
# False

# %%
s = "abc"
t = "ahbgdc"
isSubsequence(s, t)
# Out:
# True

# %%
s = "aa"
t = "a"
isSubsequence(s, t)
# Out:
# False

# %%
s = ""
t = ""
isSubsequence(s, t)
# Out:
# True

# %% [markdown]
# This solution was accepted with 0 ms Beats 100.00%

# %% [markdown]
# ### container-with-most-water

# %% [markdown]
# You are given an integer array height of length n. There are n vertical lines drawn such that the two endpoints of the ith line are (i, 0) and (i, height[i]). Find two lines that together with the x-axis form a container, such that the container contains the most water. Return the maximum amount of water a container can store.
#
# Notice that you may not slant the container.

# %%
def maxArea(height):
        """
        :type height: List[int]
        :rtype: int
        """
        left=0
        right=len(height)-1
        sub=0
        while left<right:
                sub_n = min(height[left],height[right])*(right-left)
                if sub_n > sub:
                        sub = sub_n
                if height[left] < height[right]:
                        left += 1
                else: right -= 1
        return sub

# %%
height = [1,8,6,2,5,4,8,3,7] #49
maxArea(height)
# Out:
# 49

# %%
height = [1,2,1] #2
maxArea(height)
# Out:
# 2

# %%
height = [8,7,2,1] #7
maxArea(height)
# Out:
# 7

# %% [markdown]
# This solution was accepted with 79 ms Beats 91.91%

# %% [markdown]
# ### max-number-of-k-sum-pairs

# %% [markdown]
# You are given an integer array nums and an integer k.
# In one operation, you can pick two numbers from the array whose sum equals k and remove them from the array.
#
# Return the maximum number of operations you can perform on the array.

# %%
def maxOperations(nums, k):
        """
        :type nums: List[int]
        :type k: int
        """
        col=0
        end=len(nums)-1
        start=0
        nums=sorted(nums)
        while start<end:
                #print(start)
                if nums[start] + nums[end] == k:
                        start+=1
                        end-=1
                        col+=1
                elif nums[start] + nums[end] < k:
                        start+=1
                else:
                        end-=1
        return col

# %%
nums = [4,4,1,3,1,3,2,2,5,5,1,5,2,1,2,3,5,4] #2
k = 2
maxOperations(nums, k)
# Out:
# 2

# %%
nums = [3,1,3,4,3] #1
k = 6
maxOperations(nums, k)
# Out:
# 1

# %% [markdown]
# This solution was accepted with 585 ms Beats 8.77%

# %%
def maxOperations(nums, k):
        """
        :type nums: List[int]
        :type k: int
        """
        freq={}
        cnt=0
        for num in nums:
                a = k - num
                if freq.get(a,0) > 0:
                        cnt += 1
                        freq[a] -= 1
                else:
                        freq[num] = freq.get(num,0) + 1
        return cnt

# %%
nums = [4,4,1,3,1,3,2,2,5,5,1,5,2,1,2,3,5,4] #2
k = 2
maxOperations(nums, k)
# Out:
# 2

# %%
nums = [3,1,3,4,3] #1
k = 6
maxOperations(nums, k)
# Out:
# 1

# %%
nums = [0, 0, 0] #1
k = 0
maxOperations(nums, k)
# Out:
# 1

# %% [markdown]
# This solution was accepted with 540 ms Beats 52.22%
