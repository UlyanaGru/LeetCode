# %% [markdown]
# ### maximum-average-subarray-i

# %% [markdown]
# You are given an integer array nums consisting of n elements, and an integer k.
#
# Find a contiguous subarray whose length is equal to k that has the maximum average value and return this value. Any answer with a calculation error less than $10^{-5}$ will be accepted.

# %%
def findMaxAverage(nums, k):
        """
        :type nums: List[int]
        :type k: int
        :rtype: float
        """
        curr = sum(nums[:k])
        maxn = curr
        for i in range(k,len(nums)):
                curr = curr - nums[i-k] + nums[i]
                if curr>maxn: maxn=curr
        return float(maxn)/k

# %%
nums = [1,12,-5,-6,50,3] #12.75000
k = 4
findMaxAverage(nums, k)
# Out:
# 12.75

# %% [markdown]
# This solution is accepted with 43 ms Beats 89.73%

# %% [markdown]
# ### maximum-number-of-vowels-in-a-substring-of-given-length

# %% [markdown]
# Given a string s and an integer k, return the maximum number of vowel letters in any substring of s with length k.

# %%
def maxVowels(s, k):
        """
        :type s: str
        :type k: int
        :rtype: int
        """
        vowels={'a','e','i','o','u'}
        cnt=0
        for i in range(k):
                if s[i] in vowels: cnt+=1
        maxcnt=cnt
        for i in range(k,len(s)):
                if s[i-k] in vowels: cnt-=1
                if s[i] in vowels: cnt+=1
                if cnt>maxcnt: maxcnt=cnt
                if maxcnt==k: return maxcnt
        return maxcnt

# %%
s = "abciiidef" #3
k = 3
print(maxVowels(s, k))
s = "aeiou" #2
k = 2
print(maxVowels(s, k))
s = "leetcode" #2
k = 3
print(maxVowels(s, k))
s = "rhythms" #0
k = 4
print(maxVowels(s, k))
s = "weallloveyou" #4
k = 7
print(maxVowels(s, k))
s = "aeiou" #2
k = 2
print(maxVowels(s, k))
# Out:
# 3
# 2
# 2
# 0
# 4
# 2

# %% [markdown]
# This solution was accepted with 43 ms Beats 89.73%

# %% [markdown]
# ### max-consecutive-ones-iii

# %% [markdown]
# Given a binary array nums and an integer k, return the maximum number of consecutive 1's in the array if you can flip at most k 0's.
